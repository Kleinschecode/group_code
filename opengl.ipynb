# %%
# Install dependencies for headless rendering
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install pyvirtualdisplay pyglet==1.5.27 > /dev/null 2>&1

from pyvirtualdisplay import Display
import matplotlib.pyplot as plt

display = Display(visible=0, size=(400, 300))
display.start()

# %%
from OpenGL.GL import *
from OpenGL.GLUT import *
import matplotlib.pyplot as plt
import numpy as np

# 1. Setup (assuming pyvirtualdisplay is already started)
width, height = 400, 300
glutInit()
glutInitDisplayMode(GLUT_RGB)
glutInitWindowSize(width, height)
glutCreateWindow(b"Colab Render")

# 2. Draw something (e.g., a simple triangle)
glClear(GL_COLOR_BUFFER_BIT)
glBegin(GL_TRIANGLES)
glColor3f(1, 0, 0); glVertex2f(-0.5, -0.5)
glColor3f(0, 1, 0); glVertex2f(0.5, -0.5)
glColor3f(0, 0, 1); glVertex2f(0, 0.5)
glEnd()
glFlush()

# 3. Capture the "hidden" pixels
img_buf = glReadPixels(0, 0, width, height, GL_RGB, GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf, np.uint8).reshape(height, width, 3)

# 4. Display in Colab
plt.imshow(np.flipud(img)) # Flip because OpenGL starts at bottom-left
plt.axis('off')
plt.show()
